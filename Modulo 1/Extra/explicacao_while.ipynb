# %% [markdown]
#  # Laço de Repetição while em Python

# %% [markdown]
# ## O que é o while?

# %% [markdown]
# O while é usado quando não sabemos quantas vezes vamos repetir uma ação, mas sabemos a condição que precisa continuar verdadeira.
#
# Ele executa um bloco de código várias vezes, enquanto uma condição for verdadeira.

# %% [markdown]
# ## 🧠 Analogia simples

# %% [markdown]
# Imagine que você está enchendo uma garrafa com água:
#
# "Enquanto (while) a garrafa não estiver cheia, continue enchendo."
#
# Esse tipo de lógica é perfeita para o while.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A condição é avaliada antes de cada repetição.
# Quando ela for falsa, o while para.

# %% [markdown]
# ##  Exemplo 1: Contando de 1 a 5

# %%
contador = 1

while contador <= 5:
    print("Contando:", contador)
    contador += 1  # aumenta o valor de contador em 1
# Out:
# Contando: 1
# Contando: 2
# Contando: 3
# Contando: 4
# Contando: 5

# %% [markdown]
# 🎯 Neste exemplo:
#
# - A variável contador começa em 1.
# - Enquanto contador <= 5, o programa imprime o valor e soma 1.
# - Quando contador chega a 6, a condição se torna falsa e o laço para.

# %% [markdown]
# ⚠️ Cuidado com laço infinito!
# - Se você esquecer de atualizar a variável, o laço nunca para, o que pode travar seu programa.

# %%
contador = 1

while contador <= 5:
    print("Contando:", contador)
    # Se não tiver contador += 1, esse laço nunca termina!
# Out:
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# Contando: 1
# ...

# %% [markdown]
# # Percorrendo uma lista com while

# %%
# percorrendo uma lista com while
lista = ['a', 'b', 'c', 'd']
contador = 0
while contador < len(lista):
    print(lista[contador])
    contador = contador + 1
# Out:
# a
# b
# c
# d
